# %%
import setup
setup.init()

# %%
from ai.tools import list_documents,get_document

# %%
config = {
    "user_id" : 1
}

# %%
list_documents.invoke(None, config)
# Out:
# {'tags': [], 'metadata': {}, 'callbacks': None, 'recursion_limit': 25, 'configurable': {'user_id': 1}}
# [{'id': 1, 'title': 'Hellow World'}, {'id': 2, 'title': 'Title'}]

# %%
get_document.invoke({"document_id":2}, config)
# Out:
# {'id': 2, 'title': 'Title'}
