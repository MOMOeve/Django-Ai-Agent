# %%
import setup
setup.init()

# %%
from ai.llms import get_openai_model

# %%
model = get_openai_model()

# %%
model.invoke("你是谁")
# Out:
# AIMessage(content='我是一个由 OpenAI 训练的人工智能助手，可以帮你回答问题、整理信息、写作、翻译、编程辅助等。  \n如果你愿意，也可以直接告诉我你现在想做什么。', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 50, 'prompt_tokens': 8, 'total_tokens': 58, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5.4-mini-2026-03-17', 'system_fingerprint': None, 'id': 'chatcmpl-DqCiGXHCIiqy2iDYqg2t84OAUpJaS', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019ebfcc-3548-75a0-84cc-d1ade2cfb485-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 8, 'output_tokens': 50, 'total_tokens': 58, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})
