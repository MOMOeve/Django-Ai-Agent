# %%
import setup
setup.init()

# %%
from tmdb import client as tmdb_client

# %%
response = tmdb_client.search_movie("千与千寻")
results = response.get("results")
movid = results[0].get("id")
movid
# Out:
# 129

# %%
detail_response = tmdb_client.movie_detail(33)
detail_response
# Out:
# {'adult': False,
#  'backdrop_path': '/rvRGFevvZK48onX0PYI1eQLbuJd.jpg',
#  'belongs_to_collection': None,
#  'budget': 14400000,
#  'genres': [{'id': 37, 'name': '西部'}],
#  'homepage': '',
#  'id': 33,
#  'imdb_id': 'tt0105695',
#  'origin_country': ['US'],
#  'original_language': 'en',
#  'original_title': 'Unforgiven',
#  'overview': '在这部荣获奥斯卡奖的西部片中，伊斯特伍德与弗里曼饰演穷途末路的法外之徒，为获取怀俄明州偏远大威士忌镇几名复仇心切的妓女悬赏的赏金，他们最后一次拔枪上阵。',
#  'popularity': 6.4833,
#  'poster_path': '/lQlN4xwc0it85GE6OEulSa454G3.jpg',
#  'production_companies': [{'id': 174,
#    'logo_path': '/zhD3hhtKB5qyv7ZeL4uLpNxgMVU.png',
#    'name': 'Warner Bros. Pictures',
#    'origin_country': 'US'},
#   {'id': 171,
#    'logo_path': '/bqLWwuNCHcY3IjB5e4o29h7l80D.png',
#    'name': 'Malpaso Productions',
#    'origin_country': 'US'}],
#  'production_countries': [{'iso_3166_1': 'US',
#    'name': 'United States of America'}],
#  'release_date': '1992-08-07',
#  'revenue': 159157447,
#  'runtime': 130,
#  'softcore': False,
# ...
