# %%
from pygments.lexers import resource

import setup
setup.init()

# %%
from mypermit import permit_client

permit = permit_client

# %%
await permit.api.users.list()
# Out:
# PaginatedResultUserRead(data=[], total_count=0, page_count=0)

# %%
from django.contrib.auth import get_user_model

User = get_user_model()

# %%
for u in User.objects.all():
    user_data = {
        "key":f"{u.id}",
        "first_name":f"{u.username}",
    }
    response = await permit.api.users.sync(user_data)
    print(response)
# Out:
# key='1' id=UUID('c4071a25-5647-45da-a402-a99be79107da') organization_id=UUID('419ab5d3-efc6-4e7c-9612-a3e01a880644') project_id=UUID('d0e37e20-6fdd-47bc-81ff-0639500268c5') environment_id=UUID('392cc7fb-7d82-4926-813d-c0dd79e677bc') associated_tenants=[] roles=[] created_at=datetime.datetime(2026, 6, 15, 5, 2, 43, tzinfo=datetime.timezone.utc) updated_at=datetime.datetime(2026, 6, 15, 5, 6, tzinfo=datetime.timezone.utc) email=None first_name='momoeven' last_name=None attributes=None
# key='2' id=UUID('7ad33eda-8d1a-4a56-baa7-541507cfa008') organization_id=UUID('419ab5d3-efc6-4e7c-9612-a3e01a880644') project_id=UUID('d0e37e20-6fdd-47bc-81ff-0639500268c5') environment_id=UUID('392cc7fb-7d82-4926-813d-c0dd79e677bc') associated_tenants=[] roles=[] created_at=datetime.datetime(2026, 6, 15, 5, 2, 45, tzinfo=datetime.timezone.utc) updated_at=datetime.datetime(2026, 6, 15, 5, 6, 1, tzinfo=datetime.timezone.utc) email=None first_name='LL' last_name=None attributes=None
# key='3' id=UUID('8c17683b-f3e6-43c2-a8ad-3dbbcfc93143') organization_id=UUID('419ab5d3-efc6-4e7c-9612-a3e01a880644') project_id=UUID('d0e37e20-6fdd-47bc-81ff-0639500268c5') environment_id=UUID('392cc7fb-7d82-4926-813d-c0dd79e677bc') associated_tenants=[] roles=[] created_at=datetime.datetime(2026, 6, 15, 5, 2, 46, tzinfo=datetime.timezone.utc) updated_at=datetime.datetime(2026, 6, 15, 5, 6, 4, tzinfo=datetime.timezone.utc) email=None first_name='ethan_hurt' last_name=None attributes=None

# %%
await permit.check("1", "read", "document")
# Out:
# False

# %%
resources = [
    {
        "name":"Document",
        "key":"document",
        "actions":{
            "read":{},
            "create":{},
            "update":{},
            "delete":{}
        }
    },
    {
        "name":"Movie Discovery Resource",
        "key":"movie_discovery",
         "actions":{
            "search":{},
            "detail":{},
        }
    }
]

# %%
readonly_permissions = [
    "document:read",
    "movie_discovery:search",
    "movie_discovery:detail",
]

# %%
roles = [
    {
        "name":"Manager",
        "key":"manager",
        "permissions":[
            "document:read",
            "document:create",
            "document:update",
            "document:delete",
            "movie_discovery:search",
            "movie_discovery:detail",
        ]
    },
    {
        "name":"Viewer",
        "key":"viewer",
        "permissions":[
            "document:read",
            "movie_discovery:search",
            "movie_discovery:detail",
        ]
    }
]

# %%
from permit import PermitApiError
async def get_or_create_resource(resource_data:dict):
    resource_key = resource_data.get('key')
    try:
        _resource = await permit.api.resources.get(resource_key)
    except PermitApiError as e:
        if e.status_code == 404:
            _resource = await permit.api.resources.create(resource_data)
        else:
            raise e
    return _resource

# %%
for resource_data in resources:
    resource = await get_or_create_resource(resource_data)
    print(resource)
# Out:
# key='document' id=UUID('bda9bdcb-a7aa-427d-a680-490379e51cae') organization_id=UUID('419ab5d3-efc6-4e7c-9612-a3e01a880644') project_id=UUID('d0e37e20-6fdd-47bc-81ff-0639500268c5') environment_id=UUID('392cc7fb-7d82-4926-813d-c0dd79e677bc') created_at=datetime.datetime(2026, 6, 15, 5, 18, 24, tzinfo=datetime.timezone.utc) updated_at=datetime.datetime(2026, 6, 15, 5, 18, 24, tzinfo=datetime.timezone.utc) name='Document' urn='prn:momoeven:default:document' description=None actions={'update': ActionBlockRead(name='update', description=None, attributes={}, v1compat_path=None, v1compat_name=None, id=UUID('c187a333-96ee-47da-87b4-f6db8c857c05'), key='update'), 'delete': ActionBlockRead(name='delete', description=None, attributes={}, v1compat_path=None, v1compat_name=None, id=UUID('d67d8e05-dc4b-4912-963f-5bdbb62fdf77'), key='delete'), 'create': ActionBlockRead(name='create', description=None, attributes={}, v1compat_path=None, v1compat_name=None, id=UUID('6a931e42-62be-4c9c-9f31-54f25222d760'), key='create'), 'read': ActionBlockRead(name='read', description=None, attributes={}, v1compat_path=None, v1compat_name=None, id=UUID('20f34877-54e1-47d1-82df-cc3313a9da39'), key='read')} type_attributes=None attributes={} roles={} relations={} v1compat_path=None v1compat_type=None v1compat_name=None action_groups={}
# key='movie_discovery' id=UUID('94cb8a2d-3655-447a-b43f-e3b1acf45842') organization_id=UUID('419ab5d3-efc6-4e7c-9612-a3e01a880644') project_id=UUID('d0e37e20-6fdd-47bc-81ff-0639500268c5') environment_id=UUID('392cc7fb-7d82-4926-813d-c0dd79e677bc') created_at=datetime.datetime(2026, 6, 15, 5, 36, 22, tzinfo=datetime.timezone.utc) updated_at=datetime.datetime(2026, 6, 15, 5, 36, 22, tzinfo=datetime.timezone.utc) name='Movie Discovery Resource' urn='prn:momoeven:default:movie_discovery' description=None actions={'search': ActionBlockRead(name='search', description=None, attributes={}, v1compat_path=None, v1compat_name=None, id=UUID('023b3195-7911-41b3-8351-a4d86a3f3e1e'), key='search'), 'detail': ActionBlockRead(name='detail', description=None, attributes={}, v1compat_path=None, v1compat_name=None, id=UUID('0e38c00c-2308-4ee0-bf8d-e13808327426'), key='detail')} type_attributes=None attributes={} roles={} relations={} v1compat_path=None v1compat_type=None v1compat_name=None action_groups={}

# %%
await get_or_create_resource({"key":"document"})
# Out:
# ResourceRead(key='document', id=UUID('bda9bdcb-a7aa-427d-a680-490379e51cae'), organization_id=UUID('419ab5d3-efc6-4e7c-9612-a3e01a880644'), project_id=UUID('d0e37e20-6fdd-47bc-81ff-0639500268c5'), environment_id=UUID('392cc7fb-7d82-4926-813d-c0dd79e677bc'), created_at=datetime.datetime(2026, 6, 15, 5, 18, 24, tzinfo=datetime.timezone.utc), updated_at=datetime.datetime(2026, 6, 15, 5, 18, 24, tzinfo=datetime.timezone.utc), name='Document', urn='prn:momoeven:default:document', description=None, actions={'update': ActionBlockRead(name='update', description=None, attributes={}, v1compat_path=None, v1compat_name=None, id=UUID('c187a333-96ee-47da-87b4-f6db8c857c05'), key='update'), 'delete': ActionBlockRead(name='delete', description=None, attributes={}, v1compat_path=None, v1compat_name=None, id=UUID('d67d8e05-dc4b-4912-963f-5bdbb62fdf77'), key='delete'), 'create': ActionBlockRead(name='create', description=None, attributes={}, v1compat_path=None, v1compat_name=None, id=UUID('6a931e42-62be-4c9c-9f31-54f25222d760'), key='create'), 'read': ActionBlockRead(name='read', description=None, attributes={}, v1compat_path=None, v1compat_name=None, id=UUID('20f34877-54e1-47d1-82df-cc3313a9da39'), key='read')}, type_attributes=None, attributes={}, roles={}, relations={}, v1compat_path=None, v1compat_type=None, v1compat_name=None, action_groups={})
