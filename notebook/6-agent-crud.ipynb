# %%
import setup
setup.init()

# %%
from ai.agents import get_document_agent

# %%
import uuid
from langgraph.checkpoint.memory import InMemorySaver

config = {"configurable":{"user_id":"2", "thread_id":uuid.uuid4()}}

checkpointer = InMemorySaver()
agent = get_document_agent(checkpointer=checkpointer)

# %%
response = agent.invoke(
    {"messages":
        [
            {
                "role":"user",
                "content":"写一篇洛克王国的游戏攻略"
            }
        ]
    },
    config
)
response["messages"][-1]
# Out:
# AIMessage(content='攻略已经为您写好并成功创建啦！📝\n\n## 📋 《洛克王国新手入门攻略》已生成\n\n这篇攻略涵盖了以下 **五大板块**：\n\n| 章节 | 内容亮点 |\n|:---:|:---|\n| 🐾 **宠物选择与培养** | 开局推荐火系宠物，资质等级、性格影响详解 |\n| 📅 **日常任务与资源获取** | 每日/每周必做任务，经验与道具获取途径 |\n| 🛡️ **装备系统详解** | 装备分类、品质等级、强化优先级 |\n| ⚔️ **PK对战技巧** | 技能搭配策略、先手优势、属性克制关系 |\n| 🤝 **社交与公会** | 公会福利、组队刷本、公会战玩法 |\n\n希望对各位小洛克有所帮助！如果你还想补充其他内容或者需要修改，随时告诉我就好~ 🎮✨', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 204, 'prompt_tokens': 1625, 'total_tokens': 1829, 'completion_tokens_details': {'accepted_prediction_tokens': None, 'audio_tokens': None, 'reasoning_tokens': 13, 'rejected_prediction_tokens': None}, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 1024}, 'prompt_cache_hit_tokens': 1024, 'prompt_cache_miss_tokens': 601}, 'model_provider': 'openai', 'model_name': 'deepseek-v4-flash', 'system_fingerprint': 'fp_8b330d02d0_prod0820_fp8_kvcache_20260402', 'id': '7f6f9902-640e-4d0a-8142-8827011d673e', 'finish_reason': 'stop', 'logp
# ...

# %%
response = agent.invoke(
    {"messages":
        [
            {
                "role":"user",
                "content":"将它保存到我的文档"
            }
        ]
    },
    config
)
response["messages"][-1].content

# %%
response = agent.invoke(
    {"messages":
        [
            {
                "role":"user",
                "content":"我的文章有哪些"
            }
        ]
    },
    config
)
response["messages"][-1].content

# %%
response = agent.invoke(
    {"messages":
        [
            {
                "role":"user",
                "content":"删除id是5的文章"
            }
        ]
    },
    config
)
response["messages"][-1].content

# %%
response = agent.invoke(
    {"messages":
        [
            {
                "role":"user",
                "content":"更新id为6的鸣潮游戏攻略的标题让它看起来像总结"
            }
        ]
    },
    config
)
response["messages"][-1].content

# %%
response = agent.invoke(
    {"messages":
        [
            {
                "role":"user",
                "content":"查找现有文档列表"
            }
        ]
    },
    config
)
response["messages"][-1].content

# %%
response = agent.invoke(
    {"messages":
        [
            {
                "role":"user",
                "content":"把id为6的文章标题改得更像总结一些"
            }
        ]
    },
    config
)
response["messages"][-1].content

# %%
response = agent.invoke(
    {"messages":
        [
            {
                "role":"user",
                "content":"更新id为6的文章根据内容总结为标题"
            }
        ]
    },
    config
)
response["messages"][-1].content

# %%
response = agent.invoke(
    {"messages":
        [
            {
                "role":"user",
                "content":"更新洛克王国游戏攻略的标题让它看起来像总结"
            }
        ]
    },
    config
)
response["messages"][-1].content

# %%
response = agent.invoke(
    {"messages":
        [
            {
                "role":"user",
                "content":"查找原神的相关文章"
            }
        ]
    },
    config
)
response["messages"][-1].content
